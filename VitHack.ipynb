# %%
import bs4
from bs4 import BeautifulSoup as bsp
from lxml import html  
import requests
from time import sleep
import json
import argparse
from collections import OrderedDict
from time import sleep

# %%
# !pip install urllib2_file

# %%
from urllib.request import urlopen

# %%
html = urlopen("https://www.moneycontrol.com/financials/adaniportsspecialeconomiczone/balance-sheetVI/MPS#MPS").read()
print(html)
# Out:
# b'<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">\r\n<html xmlns="https://www.w3.org/1999/xhtml">\r\n<head>\r\n<title>Adani Ports and Special Economic Zone Balance Sheet, Adani Ports and Special Economic Zone Financial Statement & Accounts</title>\r\n<meta name="description" content="Get Adani Ports and Special Economic Zone latest Balance Sheet, Financial Statements and Adani Ports and Special Economic Zone detailed profit and loss accounts." />\r\n<meta name="keywords" content="Adani Ports and Special Economic Zone Balance Sheet, Adani Ports and Special Economic Zone, Financial Statement,Accounts,profit and loss" />\r\n\r\n<!-- Moneycontrol Common header start here -->\r\n\t<meta name=\'dailymotion-domain-verification\' content=\'dmpn9sdnwtvex9ltc\' />\r\n\r\n<style type="text/css">\r\n.PL10{padding-left:10px;}.PT5{padding-top: 5px;}.PB5{padding-bottom: 5px;}.PR10{padding-right: 10px;}.MT10{margin-top: 10px;
# ...

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
soup = BeautifulSoup(html)
soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html xmlns="https://www.w3.org/1999/xhtml">
# <head>
# <title>Adani Ports and Special Economic Zone Balance Sheet, Adani Ports and Special Economic Zone Financial Statement &amp; Accounts</title>
# <meta content="Get Adani Ports and Special Economic Zone latest Balance Sheet, Financial Statements and Adani Ports and Special Economic Zone detailed profit and loss accounts." name="description"/>
# <meta content="Adani Ports and Special Economic Zone Balance Sheet, Adani Ports and Special Economic Zone, Financial Statement,Accounts,profit and loss" name="keywords"/>
# <!-- Moneycontrol Common header start here -->
# <meta content="dmpn9sdnwtvex9ltc" name="dailymotion-domain-verification"/>
# <style type="text/css">
# ...

# %%
response = requests.get("https://www.moneycontrol.com/financials/adaniportsspecialeconomiczone/balance-sheetVI/MPS#MPS")
content = response.content
soup = BeautifulSoup(content,"html.parser")
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.

# %%
print(soup.table)
# Out:
# <table border="0" cellpadding="0" cellspacing="0">
# <tr><td><link href="http://www.moneycontrol.com/rss/latestnews.xml" rel="alternate" title="MoneyControl.com News" type="application/rss+xml"/></td></tr>
# </table>

# %%
tables=soup.find_all('table')
# Out:
# [<table border="0" cellpadding="0" cellspacing="0">
#  <tr><td><link href="http://www.moneycontrol.com/rss/latestnews.xml" rel="alternate" title="MoneyControl.com News" type="application/rss+xml"/></td></tr>
#  </table>,
#  <table border="0" cellpadding="0" cellspacing="0" class="table4" style="PT15">
#  <tr>
#  <td align="right" class="det">
#  <span class="gD_12nb">Download Annual Report</span>
#  <span class="pdficn"></span>
#  <span class="gD_10ita">PDF Format</span>
#  <span class="awricn"></span>
# ...

# %%
headtables=soup.find_all('td')
headtables
# Out:
# [<td><link href="http://www.moneycontrol.com/rss/latestnews.xml" rel="alternate" title="MoneyControl.com News" type="application/rss+xml"/></td>,
#  <td align="right" class="det">
#  <span class="gD_12nb">Download Annual Report</span>
#  <span class="pdficn"></span>
#  <span class="gD_10ita">PDF Format</span>
#  <span class="awricn"></span>
# ...
